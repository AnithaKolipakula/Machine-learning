# %% [markdown]
# **EDA_Exploratory data analysis**

# %%
#take data and create dataframe
#this is METHOD1 to upload file and write its path
import pandas as pd
df1=pd.read_csv("dataset.zip")
df1

# %%
#METHOD2 to copy url
#in google search fruits with colours kaggle
#in both cases we get same output
df2=pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230316%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230316T144458Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
df2
# Out:
#    fruit_label\tfruit_name\tfruit_subtype\tmass\twidth\theight\tcolor_score
# 0         1\tapple\tgranny_smith\t192\t8.4\t7.3\t0.55
# 1         1\tapple\tgranny_smith\t180\t8.0\t6.8\t0.59
# 2         1\tapple\tgranny_smith\t176\t7.4\t7.2\t0.60
# 3          2\tmandarin\tmandarin\t86 \t6.2\t4.7\t0.80
# 4          2\tmandarin\tmandarin\t84 \t6.0\t4.6\t0.79
# 5          2\tmandarin\tmandarin\t80 \t5.8\t4.3\t0.77
# 6         2\tmandarin\tmandarin\t80 \t5.9 \t4.3\t0.81
# 7           2\tmandarin\tmandarin\t76\t5.8\t4.0\t0.81
# 8             1\tapple\tbraeburn\t178\t7.1\t7.8\t0.92
# 9             1\tapple\tbraeburn\t172\t7.4\t7.0\t0.89
# 10            1\tapple\tbraeburn\t166\t6.9\t7.3\t0.93
# 11            1\tapple\tbraeburn\t172\t7.1\t7.6\t0.92
# 12            1\tapple\tbraeburn\t154\t7.0\t7.1\t0.88
# 13    1\tapple\tgolden_delicious\t164\t7.3\t7.7\t0.70
# 14    1\tapple\tgolden_delicious\t152\t7.6\t7.3\t0.69
# 15    1\tapple\tgolden_delicious\t156\t7.7\t7.1\t0.69
# ...

# %%
#now to seperate output
df1=pd.read_csv("dataset.zip",sep="\t")
df1
#we get a clear output
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df1.shape#number of rows and columns
# Out:
# (59, 7)

# %%
df1.size# total number of elements
# Out:
# 413

# %%
df1.info

# %% [markdown]
# Slicing

# %%
#syntax-[inclusiverows:exclusive,inclusivecolumns:exclusive]
df1.iloc[0:10,0:6]#to get 9 rows and 5 colums we need that iloc
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height
# 0            1      apple  granny_smith   192    8.4     7.3
# 1            1      apple  granny_smith   180    8.0     6.8
# 2            1      apple  granny_smith   176    7.4     7.2
# 3            2   mandarin      mandarin    86    6.2     4.7
# 4            2   mandarin      mandarin    84    6.0     4.6
# 5            2   mandarin      mandarin    80    5.8     4.3
# 6            2   mandarin      mandarin    80    5.9     4.3
# 7            2   mandarin      mandarin    76    5.8     4.0
# 8            1      apple      braeburn   178    7.1     7.8
# 9            1      apple      braeburn   172    7.4     7.0

# %%
df1[5:8]#to get only rows
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 5            2   mandarin      mandarin    80    5.8     4.3         0.77
# 6            2   mandarin      mandarin    80    5.9     4.3         0.81
# 7            2   mandarin      mandarin    76    5.8     4.0         0.81

# %%
#i want number of unique names in fruit column
df1["fruit_name"].nunique()
# Out:
# 4

# %%
df1["fruit_name"].unique()
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
df1.groupby("fruit_name").size()
# Out:
# fruit_name
# apple       19
# lemon       16
# mandarin     5
# orange      19
# dtype: int64
