# %% [markdown]
# **TO BUILD A MODEL**

# %%
#MACHINE LEARNING-SUPERVISED MODEL-REGRESSION-LINEAR REGRESSION
#UNIVARIATE DATASET-one input column and one output column
#MULTIVARIATE DATASET-multiple input columns and one output column

# %% [markdown]
# **#step1:take data and create dataframe areavsprices**

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/ameenmanna8824/DATASETS/main/areavsprices.csv")
df
#imagine that a property broker comes to u and given below dataset and ask to create a model that
#predicts prices based on the data given
# Out:
#    Area   Prices
# 0  1000   550000
# 1  1500   800000
# 2  1800  1050000
# 3  2400  1240000
# 4  3000  1400000
# 5  3500  1650000

# %% [markdown]
# **Step2:preprocessing : now not required**

# %% [markdown]
# **step3:data visualization:to create graphs**

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Area'],df['Prices'])#here area and prices are case senstive

# %% [markdown]
# **Step4:divide data into input and output**

# %%
#input:area
#output:prices so to extract only area coulmn in dataset
x=df.iloc[0:6,0:1].values#to convert itnro array
x
# Out:
# array([[1000],
#        [1500],
#        [1800],
#        [2400],
#        [3000],
#        [3500]])

# %%
#in above table in 2d when there ':' in column if
y=df.iloc[:,1].values
y#now  1 dimensional
# Out:
# array([ 550000,  800000, 1050000, 1240000, 1400000, 1650000])

# %%
#now X=input values such as area values
#Y=output values such as column values(actual output)

# %% [markdown]
# **Step5:train and test variables**

# %%
#we not perform step5 beacuse limited data and only for multivariate data

# %% [markdown]
# **Step6:Normalisation/scaling**

# %%
#to be done only for multi vatriables:that have two column inputs and one column outpu

# %% [markdown]
# **Step7:Run a classifier/regressor/clusterer**

# %%
from sklearn.linear_model import LinearRegression
# that is sklearn.linearmodel is a package and linera regression is library
temp=LinearRegression()
#instead of creating an alisa for linear regression we store it in avariable
#and can use as a method

# %% [markdown]
# **Step8:Fitting the model(mapping)**

# %%
#nothing but plotting inputs with outputs
temp.fit(x,y)#that is we are plotting above x,y values in linear regression
# Out:
# LinearRegression()

# %% [markdown]
# **Step9:Predict the output**

# %%
#output is prices it is in y that is prices
#but we predict the output using input values x
y_pred=temp.predict(x)
y_pred
# Out:
# array([ 611053.81165919,  821031.39013453,  947017.93721973,
#        1198991.03139013, 1450964.12556054, 1660941.70403587])

# %%
y#actual output
# Out:
# array([ 550000,  800000, 1050000, 1240000, 1400000, 1650000])

# %%
#the predicted values are bit different from actual values 
#since because of linearity depends on nature of data and size
#more size more linear so huge difference

# %% [markdown]
# **Our test**

# %%
#now land seller checks with his area value
temp.predict([[3000]])#2 brackets since 2D
# Out:
# array([1450964.12556054])

# %%
#Cross verification
#we know y=mx+c where x in graph is area 3000 i need y value
#y:independent variable
#x:dependent variable
#c:y intercept......m:slope
#m=? andc=? to find y;
m=temp.coef_
m
# Out:
# array([419.95515695])

# %%
#to find c value
c=temp.intercept_
c
# Out:
# 191098.65470852004

# %%
#find y
y_check=m*3000+c
y_check
# Out:
# array([1450964.12556054])

# %%
temp.predict([[3000]])
# Out:
# array([1450964.12556054])

# %%
#Visualiztion for the bestfit line
plt.scatter(x,y)
plt.plot(x,y_pred,color='red')
#that is best fit line those points scatter due to lack of linearity
plt.title('BEST FIT LINE')
# Out:
# Text(0.5, 1.0, 'BEST FIT LINE')
